# %%
import matplotlib.pyplot as plt

# %%
import torch
import sklearn

# %% [markdown]
# # Calling the make regression utility of scikit learn to create a synthetic data set of 1 feature
# # Then convert into a tensor

# %%
from sklearn.datasets import make_regression

# %%
x,y=make_regression(30,1)

# %%
y= y.reshape(30,1)

# %%
x=torch.tensor(x, dtype=torch.float32)
y=torch.tensor(y, dtype= torch.float32)

# %%
x
# Out:
# tensor([[-0.6833],
#         [ 2.2977],
#         [-0.1394],
#         [-0.0862],
#         [-0.1290],
#         [ 0.1383],
#         [ 0.1044],
#         [-0.6146],
#         [-0.4309],
#         [-0.6575],
#         [-0.7336],
#         [ 0.1666],
#         [-0.2158],
#         [ 0.4528],
#         [-0.3510],
#         [ 0.6222],
#         [-1.5834],
#         [ 0.5952],
#         [-0.3408],
#         [ 0.0817],
#         [ 0.1949],
#         [ 0.3063],
#         [ 1.7805],
#         [ 0.7802],
#         [ 1.4357],
#         [ 3.0369],
#         [-1.3406],
#         [ 0.5757],
#         [ 0.0871],
#         [ 0.0811]])

# %%
from  torch import nn

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.layer = nn.Linear(1, 1)
        
    def forward(self, x):
        x = self.layer(x)
        return x

# %%
m=model()

# %%
m.parameters
# Out:
# <bound method Module.parameters of model(
#   (layer): Linear(in_features=1, out_features=1, bias=True)
# )>

# %%
define_criterion = torch.nn.MSELoss()

SGD_optimizer = torch.optim.SGD(m.parameters(), lr=0.1)

# %%
for epoch in range(50): 

  
    predict_y = m(x) 
    loss = define_criterion(predict_y, y) 

  
     
    loss.backward() 

    SGD_optimizer.step() 
    SGD_optimizer.zero_grad()
    print('epoch {}, loss function {}'.format(epoch, loss.item()))
# Out:
# epoch 0, loss function 0.6203936338424683
# epoch 1, loss function 0.41774216294288635
# epoch 2, loss function 0.28308627009391785
# epoch 3, loss function 0.19295383989810944
# epoch 4, loss function 0.13220937550067902
# epoch 5, loss function 0.09101198613643646
# epoch 6, loss function 0.06291087716817856
# epoch 7, loss function 0.043643709272146225
# epoch 8, loss function 0.03037259541451931
# epoch 9, loss function 0.021194402128458023
# epoch 10, loss function 0.01482428703457117
# epoch 11, loss function 0.010389473289251328
# epoch 12, loss function 0.007293765898793936
# epoch 13, loss function 0.005127874668687582
# epoch 14, loss function 0.00360956066288054
# epoch 15, loss function 0.0025434300769120455
# epoch 16, loss function 0.00179375265724957
# epoch 17, loss function 0.0012659712228924036
# epoch 18, loss function 0.0008940318366512656
# epoch 19, loss function 0.0006316935759969056
# epoch 20, loss function 0.00044652583892457187
# epoch 21, loss function 0.00031575033790431917
# epoch 22, loss function 0.00022334378445520997
# epoch 23, loss function 0.00015802030975464731
# epoch 24, loss function 0.00011182663001818582
# epoch 25, loss function 7.915082824183628e-05
# epoch 26, loss function 5.603145473287441e-05
# epoch 27, loss function 3.966948497691192e-05
# epoch 28, loss function 2.8088601538911462e-05
# epoch 29, loss function 1.9890507246600464e-05
# epoch 30, loss function 1.4085974726185668e-05
# epoch 31, loss function 9.975885404855944e-06
# epoch 32, loss function 7.065314093779307e-06
# epoch 33, loss function 5.004169452149654e-06
# epoch 34, loss function 3.544601895555388e-06
# epoch 35, loss function 2.5106498924287735e-06
# epoch 36, loss function 1.7784984720492503e-06
# epoch 37, loss function 1.2598113698913949e-06
# epoch 38, loss function 8.924255894271482e-07
# epoch 39, loss function 6.321166665657074e-07
# epoch 40, loss function 4.4783067210119043e-07
# epoch 41, loss function 3.1723547522233275e-07
# epoch 42, loss function 2.2474500838143285e-07
# epoch 43, loss function 1.5920754492526612e-07
# epoch 44, loss function 1.1279076517212161e-07
# epoch 45, loss function 7.991195616341429e-08
# epoch 46, loss function 5.661922486410731e-08
# epoch 47, loss function 4.0100715636981477e-08
# epoch 48, loss function 2.8407230345806056e-08
# epoch 49, loss function 2.0118303467597798e-08

# %%
plt.scatter(x,y)
plt.plot(x, m(x).detach())

# %% [markdown]
# # The muti Label Example

# %%
x2,y2= make_regression(100, 1, n_targets=2)

# %%
y2
# Out:
# array([[ -30.89776149,  -52.78737038],
#        [  47.95005611,   81.92041266],
#        [ 119.7763575 ,  204.63226594],
#        [  18.35384964,   31.35668774],
#        [ -10.80101155,  -18.45301956],
#        [  14.30255342,   24.43523894],
#        [ -28.50151528,  -48.69349658],
#        [ -54.42386263,  -92.98060621],
#        [ -28.73476737,  -49.09199679],
#        [ -32.31416931,  -55.20723644],
#        [  14.67293946,   25.06802604],
#        [ -61.01813429, -104.2466088 ],
#        [   3.29800394,    5.63448442],
#        [ -15.86959582,  -27.11245709],
#        [ -23.98279328,  -40.97347285],
#        [  25.28398347,   43.19649502],
#        [ -23.80980383,  -40.67792853],
#        [   4.78694252,    8.17826586],
#        [ -19.62652088,  -33.53098661],
#        [ -17.58404614,  -30.0415147 ],
#        [ -38.76462666,  -66.22753904],
#        [   8.07697716,   13.79913509],
#        [   3.34154144,    5.70886618],
#        [  13.70237989,   23.40987073],
#        [  22.04855231,   37.66891326],
#        [  12.59937034,   21.52543085],
#        [  16.14908777,   27.58995592],
#        [ -91.51863126, -156.35527144],
#        [  -1.81538881,   -3.10150629],
#        [ -37.76957915,  -64.52754722],
#        [  26.53356089,   45.33133918],
#        [  37.82979586,   64.63042464],
#        [ -29.57462068,  -50.52684661],
#        [ -15.4251701 ,  -26.35317667],
#        [  41.41625814,   70.75772654],
#        [  10.4819095 ,   17.90784874],
#        [ -18.13489293,  -30.98261051],
#        [  31.58016643,   53.95322707],
#        [ -17.23096426,  -29.43829094],
#        [  25.03347112,   42.76850645],
#        [  12.18444486,   20.81655022],
#        [   5.35841354,    9.15459717],
#        [  91.66823102,  156.61085559],
#        [  21.91452368,   37.43993164],
#        [ -16.79468249,  -28.6929241 ],
#        [  43.68534943,   74.63436214],
#        [  -2.84478339,   -4.86017844],
#        [  44.02044885,   75.20686372],
#        [ -84.34996582, -144.10794415],
#        [ -56.5557079 ,  -96.62276346],
#        [  45.47829065,   77.69751778],
#        [  35.80581098,   61.17254179],
#        [  56.51815422,   96.55860477],
#        [  19.7930573 ,   33.81550625],
#        [  33.21914389,   56.75334289],
#        [ -43.03661717,  -73.52603362],
#        [ -28.87367192,  -49.32930868],
#        [ -27.52505885,  -47.02526676],
#        [  19.58938393,   33.46753988],
#        [   6.60652378,   11.28693474],
#        [  -8.03533696,  -13.72799477],
#        [ -43.13259522,  -73.6900076 ],
#        [ -35.93697588,  -61.39663084],
#        [ -22.84622308,  -39.0316962 ],
#        [  -2.20430184,   -3.76594588],
#        [ -10.79122315,  -18.43629653],
#        [ -16.93741712,  -28.93677948],
#        [  -4.81669087,   -8.22908951],
#        [  -2.21545746,   -3.78500473],
#        [  -1.58620789,   -2.70996148],
#        [  13.6484174 ,   23.31767837],
#        [  21.15518472,   36.14263679],
#        [  15.88371136,   27.13657282],
#        [  19.46186595,   33.24968142],
#        [ -35.23825457,  -60.2028984 ],
#        [ -29.7275256 ,  -50.78807748],
#        [ -30.37601724,  -51.8959949 ],
#        [   3.3354229 ,    5.69841295],
#        [  49.52766838,   84.61568893],
#        [  44.33007368,   75.73584316],
#        [ -50.10230073,  -85.59742123],
#        [  17.38986766,   29.70976992],
#        [  17.41810304,   29.75800874],
#        [  22.6336964 ,   38.66860437],
#        [  57.86002863,   98.851134  ],
#        [ -41.87089256,  -71.53444803],
#        [ -44.75963458,  -76.46972773],
#        [ -20.68653749,  -35.34197507],
#        [  30.69251578,   52.43671774],
#        [  41.35625057,   70.65520644],
#        [  23.6521251 ,   40.40854183],
#        [  27.83270202,   47.55086062],
#        [  44.12331004,   75.38259721],
#        [  23.32166045,   39.84395854],
#        [ -45.70588718,  -78.08635573],
#        [  22.52140003,   38.47675131],
#        [  30.28333506,   51.73765176],
#        [  60.63056317,  103.58446179],
#        [  -4.55408906,   -7.78044668],
#        [ -25.147485  ,  -42.9632938 ]])

# %%
x2=torch.tensor(x2, dtype=torch.float32)
y2=torch.tensor(y2, dtype= torch.float32)

# %%
x2
# Out:
# tensor([[-0.8289],
#         [ 1.2863],
#         [ 3.2132],
#         [ 0.4924],
#         [-0.2898],
#         [ 0.3837],
#         [-0.7646],
#         [-1.4600],
#         [-0.7709],
#         [-0.8669],
#         [ 0.3936],
#         [-1.6369],
#         [ 0.0885],
#         [-0.4257],
#         [-0.6434],
#         [ 0.6783],
#         [-0.6387],
#         [ 0.1284],
#         [-0.5265],
#         [-0.4717],
#         [-1.0399],
#         [ 0.2167],
#         [ 0.0896],
#         [ 0.3676],
#         [ 0.5915],
#         [ 0.3380],
#         [ 0.4332],
#         [-2.4551],
#         [-0.0487],
#         [-1.0132],
#         [ 0.7118],
#         [ 1.0148],
#         [-0.7934],
#         [-0.4138],
#         [ 1.1111],
#         [ 0.2812],
#         [-0.4865],
#         [ 0.8472],
#         [-0.4622],
#         [ 0.6716],
#         [ 0.3269],
#         [ 0.1437],
#         [ 2.4591],
#         [ 0.5879],
#         [-0.4505],
#         [ 1.1719],
#         [-0.0763],
#         [ 1.1809],
#         [-2.2628],
#         [-1.5172],
#         [ 1.2200],
#         [ 0.9605],
#         [ 1.5162],
#         [ 0.5310],
#         [ 0.8912],
#         [-1.1545],
#         [-0.7746],
#         [-0.7384],
#         [ 0.5255],
#         [ 0.1772],
#         [-0.2156],
#         [-1.1571],
#         [-0.9641],
#         [-0.6129],
#         [-0.0591],
#         [-0.2895],
#         [-0.4544],
#         [-0.1292],
#         [-0.0594],
#         [-0.0426],
#         [ 0.3661],
#         [ 0.5675],
#         [ 0.4261],
#         [ 0.5221],
#         [-0.9453],
#         [-0.7975],
#         [-0.8149],
#         [ 0.0895],
#         [ 1.3287],
#         [ 1.1892],
#         [-1.3441],
#         [ 0.4665],
#         [ 0.4673],
#         [ 0.6072],
#         [ 1.5522],
#         [-1.1233],
#         [-1.2007],
#         [-0.5549],
#         [ 0.8234],
#         [ 1.1094],
#         [ 0.6345],
#         [ 0.7467],
#         [ 1.1837],
#         [ 0.6256],
#         [-1.2261],
#         [ 0.6042],
#         [ 0.8124],
#         [ 1.6265],
#         [-0.1222],
#         [-0.6746]])

# %%
y2
# Out:
# tensor([[ -30.8978,  -52.7874],
#         [  47.9501,   81.9204],
#         [ 119.7764,  204.6323],
#         [  18.3538,   31.3567],
#         [ -10.8010,  -18.4530],
#         [  14.3026,   24.4352],
#         [ -28.5015,  -48.6935],
#         [ -54.4239,  -92.9806],
#         [ -28.7348,  -49.0920],
#         [ -32.3142,  -55.2072],
#         [  14.6729,   25.0680],
#         [ -61.0181, -104.2466],
#         [   3.2980,    5.6345],
#         [ -15.8696,  -27.1125],
#         [ -23.9828,  -40.9735],
#         [  25.2840,   43.1965],
#         [ -23.8098,  -40.6779],
#         [   4.7869,    8.1783],
#         [ -19.6265,  -33.5310],
#         [ -17.5840,  -30.0415],
#         [ -38.7646,  -66.2275],
#         [   8.0770,   13.7991],
#         [   3.3415,    5.7089],
#         [  13.7024,   23.4099],
#         [  22.0486,   37.6689],
#         [  12.5994,   21.5254],
#         [  16.1491,   27.5900],
#         [ -91.5186, -156.3553],
#         [  -1.8154,   -3.1015],
#         [ -37.7696,  -64.5275],
#         [  26.5336,   45.3313],
#         [  37.8298,   64.6304],
#         [ -29.5746,  -50.5268],
#         [ -15.4252,  -26.3532],
#         [  41.4163,   70.7577],
#         [  10.4819,   17.9078],
#         [ -18.1349,  -30.9826],
#         [  31.5802,   53.9532],
#         [ -17.2310,  -29.4383],
#         [  25.0335,   42.7685],
#         [  12.1844,   20.8165],
#         [   5.3584,    9.1546],
#         [  91.6682,  156.6109],
#         [  21.9145,   37.4399],
#         [ -16.7947,  -28.6929],
#         [  43.6853,   74.6344],
#         [  -2.8448,   -4.8602],
#         [  44.0205,   75.2069],
#         [ -84.3500, -144.1079],
#         [ -56.5557,  -96.6228],
#         [  45.4783,   77.6975],
#         [  35.8058,   61.1725],
#         [  56.5182,   96.5586],
#         [  19.7931,   33.8155],
#         [  33.2191,   56.7533],
#         [ -43.0366,  -73.5260],
#         [ -28.8737,  -49.3293],
#         [ -27.5251,  -47.0253],
#         [  19.5894,   33.4675],
#         [   6.6065,   11.2869],
#         [  -8.0353,  -13.7280],
#         [ -43.1326,  -73.6900],
#         [ -35.9370,  -61.3966],
#         [ -22.8462,  -39.0317],
#         [  -2.2043,   -3.7659],
#         [ -10.7912,  -18.4363],
#         [ -16.9374,  -28.9368],
#         [  -4.8167,   -8.2291],
#         [  -2.2155,   -3.7850],
#         [  -1.5862,   -2.7100],
#         [  13.6484,   23.3177],
#         [  21.1552,   36.1426],
#         [  15.8837,   27.1366],
#         [  19.4619,   33.2497],
#         [ -35.2383,  -60.2029],
#         [ -29.7275,  -50.7881],
#         [ -30.3760,  -51.8960],
#         [   3.3354,    5.6984],
#         [  49.5277,   84.6157],
#         [  44.3301,   75.7358],
#         [ -50.1023,  -85.5974],
#         [  17.3899,   29.7098],
#         [  17.4181,   29.7580],
#         [  22.6337,   38.6686],
#         [  57.8600,   98.8511],
#         [ -41.8709,  -71.5344],
#         [ -44.7596,  -76.4697],
#         [ -20.6865,  -35.3420],
#         [  30.6925,   52.4367],
#         [  41.3563,   70.6552],
#         [  23.6521,   40.4085],
#         [  27.8327,   47.5509],
#         [  44.1233,   75.3826],
#         [  23.3217,   39.8440],
#         [ -45.7059,  -78.0864],
#         [  22.5214,   38.4767],
#         [  30.2833,   51.7377],
#         [  60.6306,  103.5845],
#         [  -4.5541,   -7.7804],
#         [ -25.1475,  -42.9633]])

# %%
class model2(nn.Module):
    def __init__(self):
        super(model2, self).__init__()
        self.layer = nn.Linear(1, 2)
        
    def forward(self, x):
        x = self.layer(x)
        return x

# %%
m2=model2()

# %%
define_criterion = torch.nn.MSELoss()

SGD_optimizer = torch.optim.SGD(m2.parameters(), lr=0.1)

# %%
for epoch in range(500): 

  
    predict_y2 = m2(x2) 
    loss2 = define_criterion(predict_y2, y2) 

  
     
    loss2.backward() 

    SGD_optimizer.step() 
    SGD_optimizer.zero_grad()
    print('epoch {}, loss function {}'.format(epoch, loss2.item()))
# Out:
# epoch 0, loss function 2470.05615234375
# epoch 1, loss function 2046.293701171875
# epoch 2, loss function 1695.46826171875
# epoch 3, loss function 1404.9814453125
# epoch 4, loss function 1164.419189453125
# epoch 5, loss function 965.172119140625
# epoch 6, loss function 800.1207885742188
# epoch 7, loss function 663.3770141601562
# epoch 8, loss function 550.0702514648438
# epoch 9, loss function 456.1707763671875
# epoch 10, loss function 378.3442687988281
# epoch 11, loss function 313.8311462402344
# epoch 12, loss function 260.3472595214844
# epoch 13, loss function 216.0015869140625
# epoch 14, loss function 179.22825622558594
# epoch 15, loss function 148.73072814941406
# epoch 16, loss function 123.43502044677734
# epoch 17, loss function 102.45156860351562
# epoch 18, loss function 85.0433120727539
# epoch 19, loss function 70.59957122802734
# epoch 20, loss function 58.6142463684082
# epoch 21, loss function 48.667884826660156
# epoch 22, loss function 40.412837982177734
# epoch 23, loss function 33.56080627441406
# epoch 24, loss function 27.872817993164062
# epoch 25, loss function 23.150676727294922
# epoch 26, loss function 19.230030059814453
# epoch 27, loss function 15.974560737609863
# epoch 28, loss function 13.271187782287598
# epoch 29, loss function 11.026086807250977
# epoch 30, loss function 9.16142749786377
# epoch 31, loss function 7.612619400024414
# epoch 32, loss function 6.326059341430664
# epoch 33, loss function 5.257274150848389
# epoch 34, loss function 4.369327545166016
# epoch 35, loss function 3.631575345993042
# epoch 36, loss function 3.018568754196167
# epoch 37, loss function 2.509178876876831
# epoch 38, loss function 2.085866689682007
# epoch 39, loss function 1.7340633869171143
# epoch 40, loss function 1.4416711330413818
# epoch 41, loss function 1.1986384391784668
# epoch 42, loss function 0.9966273307800293
# epoch 43, loss function 0.8287020921707153
# epoch 44, loss function 0.6891010403633118
# epoch 45, loss function 0.573041558265686
# epoch 46, loss function 0.4765516519546509
# epoch 47, loss function 0.39632391929626465
# epoch 48, loss function 0.32961681485176086
# epoch 49, loss function 0.2741495370864868
# epoch 50, loss function 0.22802583873271942
# epoch 51, loss function 0.1896689385175705
# epoch 52, loss function 0.15777024626731873
# epoch 53, loss function 0.13123956322669983
# epoch 54, loss function 0.10917561501264572
# epoch 55, loss function 0.09082385897636414
# epoch 56, loss function 0.07555904984474182
# epoch 57, loss function 0.06286201626062393
# epoch 58, loss function 0.052300576120615005
# epoch 59, loss function 0.04351380467414856
# epoch 60, loss function 0.036204613745212555
# epoch 61, loss function 0.030124040320515633
# epoch 62, loss function 0.02506597526371479
# epoch 63, loss function 0.02085724100470543
# epoch 64, loss function 0.017355596646666527
# epoch 65, loss function 0.014442265033721924
# epoch 66, loss function 0.012018267065286636
# epoch 67, loss function 0.010001365095376968
# epoch 68, loss function 0.008323045447468758
# epoch 69, loss function 0.00692648533731699
# epoch 70, loss function 0.005764625500887632
# epoch 71, loss function 0.004797699861228466
# epoch 72, loss function 0.003992969170212746
# epoch 73, loss function 0.0033232688438147306
# epoch 74, loss function 0.0027660070918500423
# epoch 75, loss function 0.002302219159901142
# epoch 76, loss function 0.0019161499803885818
# epoch 77, loss function 0.0015949431108310819
# epoch 78, loss function 0.0013274933444336057
# epoch 79, loss function 0.0011049641761928797
# epoch 80, loss function 0.0009197724866680801
# epoch 81, loss function 0.0007655903464183211
# epoch 82, loss function 0.000637275748886168
# epoch 83, loss function 0.0005305250524543226
# epoch 84, loss function 0.00044166052248328924
# epoch 85, loss function 0.00036767966230399907
# epoch 86, loss function 0.00030608405359089375
# epoch 87, loss function 0.00025476625887677073
# epoch 88, loss function 0.0002120729477610439
# epoch 89, loss function 0.00017656270938459784
# epoch 90, loss function 0.00014698226004838943
# epoch 91, loss function 0.00012235614121891558
# epoch 92, loss function 0.00010187238513026386
# epoch 93, loss function 8.48060954012908e-05
# epoch 94, loss function 7.06033970345743e-05
# epoch 95, loss function 5.8777211961569265e-05
# epoch 96, loss function 4.891056232736446e-05
# epoch 97, loss function 4.072298179380596e-05
# epoch 98, loss function 3.390933488844894e-05
# epoch 99, loss function 2.8234930141479708e-05
# epoch 100, loss function 2.3513084670412354e-05
# epoch 101, loss function 1.957293898158241e-05
# epoch 102, loss function 1.6304404198308475e-05
# epoch 103, loss function 1.3583579857368022e-05
# epoch 104, loss function 1.1305396583338734e-05
# epoch 105, loss function 9.411653991264757e-06
# epoch 106, loss function 7.839490535843652e-06
# epoch 107, loss function 6.530653990921564e-06
# epoch 108, loss function 5.439533197204582e-06
# epoch 109, loss function 4.528428235062165e-06
# epoch 110, loss function 3.7730728763563093e-06
# epoch 111, loss function 3.141173465337488e-06
# epoch 112, loss function 2.6171724130108487e-06
# epoch 113, loss function 2.1810342332173605e-06
# epoch 114, loss function 1.816211010918778e-06
# epoch 115, loss function 1.5123056300581084e-06
# epoch 116, loss function 1.2612022146640811e-06
# epoch 117, loss function 1.0504347756068455e-06
# epoch 118, loss function 8.752825806368492e-07
# epoch 119, loss function 7.275471602952166e-07
# epoch 120, loss function 6.069795404073375e-07
# epoch 121, loss function 5.062300374447659e-07
# epoch 122, loss function 4.222925156227575e-07
# epoch 123, loss function 3.499713443488872e-07
# epoch 124, loss function 2.9155825131965685e-07
# epoch 125, loss function 2.4309028390234744e-07
# epoch 126, loss function 2.0284997503949853e-07
# epoch 127, loss function 1.6932381186052226e-07
# epoch 128, loss function 1.4047857632704108e-07
# epoch 129, loss function 1.1653357745444737e-07
# epoch 130, loss function 9.617048846166654e-08
# epoch 131, loss function 8.023665287737458e-08
# epoch 132, loss function 6.67832935619117e-08
# epoch 133, loss function 5.608265851719807e-08
# epoch 134, loss function 4.6382584883986056e-08
# epoch 135, loss function 3.8910243915779574e-08
# epoch 136, loss function 3.220698374661879e-08
# epoch 137, loss function 2.6891516569094165e-08
# epoch 138, loss function 2.2142250699630495e-08
# epoch 139, loss function 1.8715200056362846e-08
# epoch 140, loss function 1.5593556668136443e-08
# epoch 141, loss function 1.2761084633439168e-08
# epoch 142, loss function 1.0676724393476889e-08
# epoch 143, loss function 8.81941453201307e-09
# epoch 144, loss function 7.081545128073685e-09
# epoch 145, loss function 6.1406355555959635e-09
# epoch 146, loss function 5.267253300189623e-09
# epoch 147, loss function 4.395708685933641e-09
# epoch 148, loss function 3.642563140004995e-09
# epoch 149, loss function 2.9738955742431017e-09
# epoch 150, loss function 2.4114319430168507e-09
# epoch 151, loss function 2.0127759459143135e-09
# epoch 152, loss function 1.7179169198300315e-09
# epoch 153, loss function 1.407252092633371e-09
# epoch 154, loss function 1.1756313700317378e-09
# epoch 155, loss function 9.197828054752222e-10
# epoch 156, loss function 7.863729667434427e-10
# epoch 157, loss function 6.549949471690297e-10
# epoch 158, loss function 5.31916843904412e-10
# epoch 159, loss function 4.4988923697530936e-10
# epoch 160, loss function 3.7707223454752636e-10
# epoch 161, loss function 3.6869862718447166e-10
# epoch 162, loss function 3.551049454486588e-10
# epoch 163, loss function 3.521708480391794e-10
# epoch 164, loss function 3.412669313807015e-10
# epoch 165, loss function 3.352714494919695e-10
# epoch 166, loss function 3.453997921010199e-10
# epoch 167, loss function 3.4498731649179604e-10
# epoch 168, loss function 3.4424091355234054e-10
# epoch 169, loss function 3.418083593942356e-10
# epoch 170, loss function 3.374772405972948e-10
# epoch 171, loss function 3.3627911566469493e-10
# epoch 172, loss function 3.3543365307586726e-10
# epoch 173, loss function 3.3556574186022203e-10
# epoch 174, loss function 3.339180043582246e-10
# epoch 175, loss function 3.339570842086914e-10
# epoch 176, loss function 3.3375541219626825e-10
# epoch 177, loss function 3.3530206389187356e-10
# epoch 178, loss function 3.3510985653073533e-10
# epoch 179, loss function 3.343212928719197e-10
# epoch 180, loss function 3.352952360202721e-10
# epoch 181, loss function 3.3574054647544926e-10
# epoch 182, loss function 3.378651247665232e-10
# epoch 183, loss function 3.3469277349595927e-10
# epoch 184, loss function 3.349727162316185e-10
# epoch 185, loss function 3.340998311340826e-10
# epoch 186, loss function 3.3398464549527773e-10
# epoch 187, loss function 3.339849230510339e-10
# epoch 188, loss function 3.332507880760005e-10
# epoch 189, loss function 3.334463261062126e-10
# epoch 190, loss function 3.3336169935616056e-10
# epoch 191, loss function 3.325022479572226e-10
# epoch 192, loss function 3.3250002751117336e-10
# epoch 193, loss function 3.3261599030609545e-10
# epoch 194, loss function 3.328908260158414e-10
# epoch 195, loss function 3.331057096822576e-10
# epoch 196, loss function 3.331633857683869e-10
# epoch 197, loss function 3.3313385383593186e-10
# epoch 198, loss function 3.331289966101991e-10
# epoch 199, loss function 3.3245597941267135e-10
# epoch 200, loss function 3.324505948310019e-10
# epoch 201, loss function 3.324505948310019e-10
# epoch 202, loss function 3.326142972159829e-10
# epoch 203, loss function 3.324042430197238e-10
# epoch 204, loss function 3.324042430197238e-10
# epoch 205, loss function 3.324042430197238e-10
# epoch 206, loss function 3.324042430197238e-10
# epoch 207, loss function 3.317494057242243e-10
# epoch 208, loss function 3.319131358647809e-10
# epoch 209, loss function 3.319131358647809e-10
# epoch 210, loss function 3.3187647074939264e-10
# epoch 211, loss function 3.3187647074939264e-10
# epoch 212, loss function 3.3187647074939264e-10
# epoch 213, loss function 3.3188216064239384e-10
# epoch 214, loss function 3.3286440270785533e-10
# epoch 215, loss function 3.3286440270785533e-10
# epoch 216, loss function 3.3286640110929966e-10
# epoch 217, loss function 3.3286640110929966e-10
# epoch 218, loss function 3.320617669722026e-10
# epoch 219, loss function 3.3285843525909797e-10
# epoch 220, loss function 3.3285843525909797e-10
# epoch 221, loss function 3.3285843525909797e-10
# epoch 222, loss function 3.3285843525909797e-10
# epoch 223, loss function 3.320580754806457e-10
# epoch 224, loss function 3.3285843525909797e-10
# epoch 225, loss function 3.330085096564517e-10
# epoch 226, loss function 3.330085096564517e-10
# epoch 227, loss function 3.330085096564517e-10
# epoch 228, loss function 3.322081498779994e-10
# epoch 229, loss function 3.330085096564517e-10
# epoch 230, loss function 3.330085096564517e-10
# epoch 231, loss function 3.330085096564517e-10
# epoch 232, loss function 3.330085096564517e-10
# epoch 233, loss function 3.330085096564517e-10
# epoch 234, loss function 3.322081498779994e-10
# epoch 235, loss function 3.330085096564517e-10
# epoch 236, loss function 3.330085096564517e-10
# epoch 237, loss function 3.330085096564517e-10
# epoch 238, loss function 3.330085096564517e-10
# epoch 239, loss function 3.322081498779994e-10
# epoch 240, loss function 3.330085096564517e-10
# epoch 241, loss function 3.330085096564517e-10
# epoch 242, loss function 3.330085096564517e-10
# epoch 243, loss function 3.330085096564517e-10
# epoch 244, loss function 3.322081498779994e-10
# epoch 245, loss function 3.330085096564517e-10
# epoch 246, loss function 3.329982678490495e-10
# epoch 247, loss function 3.329982678490495e-10
# epoch 248, loss function 3.329982678490495e-10
# epoch 249, loss function 3.329982678490495e-10
# epoch 250, loss function 3.3219790807059724e-10
# epoch 251, loss function 3.329982678490495e-10
# epoch 252, loss function 3.329982678490495e-10
# epoch 253, loss function 3.329982678490495e-10
# epoch 254, loss function 3.329982678490495e-10
# epoch 255, loss function 3.3219790807059724e-10
# epoch 256, loss function 3.329982678490495e-10
# epoch 257, loss function 3.329982678490495e-10
# epoch 258, loss function 3.329982678490495e-10
# epoch 259, loss function 3.329982678490495e-10
# epoch 260, loss function 3.3219790807059724e-10
# epoch 261, loss function 3.329982678490495e-10
# epoch 262, loss function 3.329982678490495e-10
# epoch 263, loss function 3.329982678490495e-10
# epoch 264, loss function 3.329982678490495e-10
# epoch 265, loss function 3.329982678490495e-10
# epoch 266, loss function 3.3219790807059724e-10
# epoch 267, loss function 3.329982678490495e-10
# epoch 268, loss function 3.329982678490495e-10
# epoch 269, loss function 3.329982678490495e-10
# epoch 270, loss function 3.329982678490495e-10
# epoch 271, loss function 3.3219790807059724e-10
# epoch 272, loss function 3.329982678490495e-10
# epoch 273, loss function 3.329982678490495e-10
# epoch 274, loss function 3.329982678490495e-10
# epoch 275, loss function 3.329982678490495e-10
# epoch 276, loss function 3.3219790807059724e-10
# epoch 277, loss function 3.329982678490495e-10
# epoch 278, loss function 3.329982678490495e-10
# epoch 279, loss function 3.329982678490495e-10
# epoch 280, loss function 3.329982678490495e-10
# epoch 281, loss function 3.329982678490495e-10
# epoch 282, loss function 3.3219790807059724e-10
# epoch 283, loss function 3.329982678490495e-10
# epoch 284, loss function 3.329982678490495e-10
# epoch 285, loss function 3.329982678490495e-10
# epoch 286, loss function 3.329982678490495e-10
# epoch 287, loss function 3.3219790807059724e-10
# epoch 288, loss function 3.329982678490495e-10
# epoch 289, loss function 3.329982678490495e-10
# epoch 290, loss function 3.329982678490495e-10
# epoch 291, loss function 3.329982678490495e-10
# epoch 292, loss function 3.3219790807059724e-10
# epoch 293, loss function 3.329982678490495e-10
# epoch 294, loss function 3.329982678490495e-10
# epoch 295, loss function 3.329982678490495e-10
# epoch 296, loss function 3.329982678490495e-10
# epoch 297, loss function 3.329982678490495e-10
# epoch 298, loss function 3.3219790807059724e-10
# epoch 299, loss function 3.329982678490495e-10
# epoch 300, loss function 3.329982678490495e-10
# epoch 301, loss function 3.329982678490495e-10
# epoch 302, loss function 3.329982678490495e-10
# epoch 303, loss function 3.3219790807059724e-10
# epoch 304, loss function 3.329982678490495e-10
# epoch 305, loss function 3.329982678490495e-10
# epoch 306, loss function 3.329982678490495e-10
# epoch 307, loss function 3.329982678490495e-10
# epoch 308, loss function 3.3219790807059724e-10
# epoch 309, loss function 3.329982678490495e-10
# epoch 310, loss function 3.329982678490495e-10
# epoch 311, loss function 3.329982678490495e-10
# epoch 312, loss function 3.329982678490495e-10
# epoch 313, loss function 3.329982678490495e-10
# epoch 314, loss function 3.3219790807059724e-10
# epoch 315, loss function 3.329982678490495e-10
# epoch 316, loss function 3.329982678490495e-10
# epoch 317, loss function 3.32983501882822e-10
# epoch 318, loss function 3.329982678490495e-10
# epoch 319, loss function 3.321831421043697e-10
# epoch 320, loss function 3.329982678490495e-10
# epoch 321, loss function 3.32983501882822e-10
# epoch 322, loss function 3.329982678490495e-10
# epoch 323, loss function 3.32983501882822e-10
# epoch 324, loss function 3.3219790807059724e-10
# epoch 325, loss function 3.32983501882822e-10
# epoch 326, loss function 3.329982678490495e-10
# epoch 327, loss function 3.32983501882822e-10
# epoch 328, loss function 3.329982678490495e-10
# epoch 329, loss function 3.32983501882822e-10
# epoch 330, loss function 3.3219790807059724e-10
# epoch 331, loss function 3.32983501882822e-10
# epoch 332, loss function 3.329982678490495e-10
# epoch 333, loss function 3.32983501882822e-10
# epoch 334, loss function 3.329982678490495e-10
# epoch 335, loss function 3.321831421043697e-10
# epoch 336, loss function 3.329982678490495e-10
# epoch 337, loss function 3.32983501882822e-10
# epoch 338, loss function 3.329982678490495e-10
# epoch 339, loss function 3.32983501882822e-10
# epoch 340, loss function 3.3219790807059724e-10
# epoch 341, loss function 3.32983501882822e-10
# epoch 342, loss function 3.329982678490495e-10
# epoch 343, loss function 3.32983501882822e-10
# epoch 344, loss function 3.329982678490495e-10
# epoch 345, loss function 3.32983501882822e-10
# epoch 346, loss function 3.3219790807059724e-10
# epoch 347, loss function 3.32983501882822e-10
# epoch 348, loss function 3.329982678490495e-10
# epoch 349, loss function 3.32983501882822e-10
# epoch 350, loss function 3.329982678490495e-10
# epoch 351, loss function 3.321831421043697e-10
# epoch 352, loss function 3.329982678490495e-10
# epoch 353, loss function 3.32983501882822e-10
# epoch 354, loss function 3.329982678490495e-10
# epoch 355, loss function 3.32983501882822e-10
# epoch 356, loss function 3.3219790807059724e-10
# epoch 357, loss function 3.32983501882822e-10
# epoch 358, loss function 3.329982678490495e-10
# epoch 359, loss function 3.32983501882822e-10
# epoch 360, loss function 3.329982678490495e-10
# epoch 361, loss function 3.32983501882822e-10
# epoch 362, loss function 3.3219790807059724e-10
# epoch 363, loss function 3.32983501882822e-10
# epoch 364, loss function 3.329982678490495e-10
# epoch 365, loss function 3.32983501882822e-10
# epoch 366, loss function 3.329982678490495e-10
# epoch 367, loss function 3.321831421043697e-10
# epoch 368, loss function 3.329982678490495e-10
# epoch 369, loss function 3.32983501882822e-10
# epoch 370, loss function 3.329982678490495e-10
# epoch 371, loss function 3.32983501882822e-10
# epoch 372, loss function 3.3219790807059724e-10
# epoch 373, loss function 3.32983501882822e-10
# epoch 374, loss function 3.329982678490495e-10
# epoch 375, loss function 3.32983501882822e-10
# epoch 376, loss function 3.329982678490495e-10
# epoch 377, loss function 3.32983501882822e-10
# epoch 378, loss function 3.3219790807059724e-10
# epoch 379, loss function 3.32983501882822e-10
# epoch 380, loss function 3.329982678490495e-10
# epoch 381, loss function 3.32983501882822e-10
# epoch 382, loss function 3.329982678490495e-10
# epoch 383, loss function 3.321831421043697e-10
# epoch 384, loss function 3.329982678490495e-10
# epoch 385, loss function 3.32983501882822e-10
# epoch 386, loss function 3.329982678490495e-10
# epoch 387, loss function 3.32983501882822e-10
# epoch 388, loss function 3.3219790807059724e-10
# epoch 389, loss function 3.32983501882822e-10
# epoch 390, loss function 3.329982678490495e-10
# epoch 391, loss function 3.32983501882822e-10
# epoch 392, loss function 3.329982678490495e-10
# epoch 393, loss function 3.32983501882822e-10
# epoch 394, loss function 3.3219790807059724e-10
# epoch 395, loss function 3.32983501882822e-10
# epoch 396, loss function 3.329982678490495e-10
# epoch 397, loss function 3.32983501882822e-10
# epoch 398, loss function 3.329982678490495e-10
# epoch 399, loss function 3.321831421043697e-10
# epoch 400, loss function 3.329982678490495e-10
# epoch 401, loss function 3.32983501882822e-10
# epoch 402, loss function 3.329982678490495e-10
# epoch 403, loss function 3.32983501882822e-10
# epoch 404, loss function 3.3219790807059724e-10
# epoch 405, loss function 3.32983501882822e-10
# epoch 406, loss function 3.329982678490495e-10
# epoch 407, loss function 3.32983501882822e-10
# epoch 408, loss function 3.329982678490495e-10
# epoch 409, loss function 3.32983501882822e-10
# epoch 410, loss function 3.3219790807059724e-10
# epoch 411, loss function 3.32983501882822e-10
# epoch 412, loss function 3.329982678490495e-10
# epoch 413, loss function 3.32983501882822e-10
# epoch 414, loss function 3.329982678490495e-10
# epoch 415, loss function 3.321831421043697e-10
# epoch 416, loss function 3.329982678490495e-10
# epoch 417, loss function 3.32983501882822e-10
# epoch 418, loss function 3.329982678490495e-10
# epoch 419, loss function 3.32983501882822e-10
# epoch 420, loss function 3.3219790807059724e-10
# epoch 421, loss function 3.32983501882822e-10
# epoch 422, loss function 3.329982678490495e-10
# epoch 423, loss function 3.32983501882822e-10
# epoch 424, loss function 3.329982678490495e-10
# epoch 425, loss function 3.32983501882822e-10
# epoch 426, loss function 3.3219790807059724e-10
# epoch 427, loss function 3.32983501882822e-10
# epoch 428, loss function 3.329982678490495e-10
# epoch 429, loss function 3.32983501882822e-10
# epoch 430, loss function 3.329982678490495e-10
# epoch 431, loss function 3.321831421043697e-10
# epoch 432, loss function 3.329982678490495e-10
# epoch 433, loss function 3.32983501882822e-10
# epoch 434, loss function 3.329982678490495e-10
# epoch 435, loss function 3.32983501882822e-10
# epoch 436, loss function 3.3219790807059724e-10
# epoch 437, loss function 3.32983501882822e-10
# epoch 438, loss function 3.329982678490495e-10
# epoch 439, loss function 3.32983501882822e-10
# epoch 440, loss function 3.329982678490495e-10
# epoch 441, loss function 3.32983501882822e-10
# epoch 442, loss function 3.3219790807059724e-10
# epoch 443, loss function 3.32983501882822e-10
# epoch 444, loss function 3.329982678490495e-10
# epoch 445, loss function 3.32983501882822e-10
# epoch 446, loss function 3.329982678490495e-10
# epoch 447, loss function 3.321831421043697e-10
# epoch 448, loss function 3.329982678490495e-10
# epoch 449, loss function 3.32983501882822e-10
# epoch 450, loss function 3.329982678490495e-10
# epoch 451, loss function 3.32983501882822e-10
# epoch 452, loss function 3.3219790807059724e-10
# epoch 453, loss function 3.32983501882822e-10
# epoch 454, loss function 3.329982678490495e-10
# epoch 455, loss function 3.32983501882822e-10
# epoch 456, loss function 3.329982678490495e-10
# epoch 457, loss function 3.32983501882822e-10
# epoch 458, loss function 3.3219790807059724e-10
# epoch 459, loss function 3.32983501882822e-10
# epoch 460, loss function 3.329982678490495e-10
# epoch 461, loss function 3.32983501882822e-10
# epoch 462, loss function 3.329982678490495e-10
# epoch 463, loss function 3.321831421043697e-10
# epoch 464, loss function 3.329982678490495e-10
# epoch 465, loss function 3.32983501882822e-10
# epoch 466, loss function 3.329982678490495e-10
# epoch 467, loss function 3.32983501882822e-10
# epoch 468, loss function 3.3219790807059724e-10
# epoch 469, loss function 3.32983501882822e-10
# epoch 470, loss function 3.329982678490495e-10
# epoch 471, loss function 3.32983501882822e-10
# epoch 472, loss function 3.329982678490495e-10
# epoch 473, loss function 3.32983501882822e-10
# epoch 474, loss function 3.3219790807059724e-10
# epoch 475, loss function 3.32983501882822e-10
# epoch 476, loss function 3.329982678490495e-10
# epoch 477, loss function 3.32983501882822e-10
# epoch 478, loss function 3.329982678490495e-10
# epoch 479, loss function 3.321831421043697e-10
# epoch 480, loss function 3.329982678490495e-10
# epoch 481, loss function 3.32983501882822e-10
# epoch 482, loss function 3.329982678490495e-10
# epoch 483, loss function 3.32983501882822e-10
# epoch 484, loss function 3.3219790807059724e-10
# epoch 485, loss function 3.32983501882822e-10
# epoch 486, loss function 3.329982678490495e-10
# epoch 487, loss function 3.32983501882822e-10
# epoch 488, loss function 3.329982678490495e-10
# epoch 489, loss function 3.32983501882822e-10
# epoch 490, loss function 3.3219790807059724e-10
# epoch 491, loss function 3.32983501882822e-10
# epoch 492, loss function 3.329982678490495e-10
# epoch 493, loss function 3.32983501882822e-10
# epoch 494, loss function 3.329982678490495e-10
# epoch 495, loss function 3.321831421043697e-10
# epoch 496, loss function 3.329982678490495e-10
# epoch 497, loss function 3.32983501882822e-10
# epoch 498, loss function 3.329982678490495e-10
# epoch 499, loss function 3.32983501882822e-10

# %%
m2(x2)
# Out:
# tensor([[ -43.4661,  -28.0932],
#         [ 205.9555,  133.1207],
#         [  33.8823,   21.9010],
#         [ -18.6905,  -12.0795],
#         [  26.1169,   16.8818],
#         [  53.8055,   34.7784],
#         [ -24.5863,  -15.8902],
#         [  66.4704,   42.9643],
#         [ -30.2229,  -19.5335],
#         [ -63.9637,  -41.3419],
#         [  74.7651,   48.3256],
#         [ -85.7336,  -55.4129],
#         [ -44.5907,  -28.8201],
#         [ 136.5347,   88.2505],
#         [-246.0812, -159.0537],
#         [ 174.4149,  112.7344],
#         [ 223.6885,  144.5824],
#         [ -58.3089,  -37.6869],
#         [  20.5264,   13.2684],
#         [  -8.8322,   -5.7076],
#         [ -44.6171,  -28.8371],
#         [  67.4010,   43.5659],
#         [  40.8822,   26.4254],
#         [  97.9873,   63.3353],
#         [   3.5298,    2.2826],
#         [ 127.0279,   82.1058],
#         [-152.2971,  -98.4362],
#         [-136.1694,  -88.0121],
#         [  62.3861,   40.3244],
#         [ 127.5206,   82.4242],
#         [   7.1860,    4.6458],
#         [  41.1305,   26.5859],
#         [ 221.6156,  143.2426],
#         [-195.4448, -126.3248],
#         [  18.4111,   11.9011],
#         [ -85.4448,  -55.2262],
#         [ -13.1018,   -8.4672],
#         [ -36.5826,  -23.6440],
#         [ -19.5642,  -12.6442],
#         [  38.6735,   24.9978],
#         [ -14.7783,   -9.5508],
#         [  93.3643,   60.3472],
#         [ 194.5317,  125.7369],
#         [  89.5050,   57.8528],
#         [  26.7772,   17.3086],
#         [ -37.3675,  -24.1514],
#         [   3.5842,    2.3178],
#         [-176.9311, -114.3584],
#         [  29.0335,   18.7670],
#         [ 126.8745,   82.0066],
#         [  33.5347,   21.6763],
#         [ -99.6357,  -64.3985],
#         [  -3.8713,   -2.5011],
#         [   3.1283,    2.0231],
#         [  64.3399,   41.5873],
#         [   4.5388,    2.9348],
#         [ 134.7561,   87.1009],
#         [ -98.0729,  -63.3884],
#         [  10.4284,    6.7415],
#         [-107.7257,  -69.6274],
#         [  55.6578,   35.9756],
#         [ -51.5808,  -33.3382],
#         [ -30.1313,  -19.4742],
#         [  24.5027,   15.8385],
#         [ 179.8636,  116.2561],
#         [ 210.1716,  135.8458],
#         [-127.5413,  -82.4353],
#         [ -72.0923,  -46.5958],
#         [ -29.9348,  -19.3473],
#         [ -58.0099,  -37.4936],
#         [ -63.1473,  -40.8142],
#         [ -63.2084,  -40.8537],
#         [  69.6965,   45.0495],
#         [ -31.9513,  -20.6506],
#         [-117.2980,  -75.8146],
#         [  35.9745,   23.2533],
#         [  66.4473,   42.9494],
#         [  -0.4696,   -0.3024],
#         [  32.6950,   21.1336],
#         [ 107.3609,   69.3940],
#         [  56.0062,   36.2008],
#         [  45.1549,   29.1870],
#         [  63.7421,   41.2009],
#         [ -26.8804,  -17.3730],
#         [ -18.1863,  -11.7536],
#         [ 129.4806,   83.6910],
#         [ 191.9023,  124.0373],
#         [ -54.5152,  -35.2348],
#         [ -75.2912,  -48.6634],
#         [ -44.9516,  -29.0534],
#         [ -22.9200,  -14.8132],
#         [ 162.4050,  104.9717],
#         [ -19.4669,  -12.5813],
#         [  42.7613,   27.6400],
#         [ 106.6262,   68.9191],
#         [ -81.6995,  -52.8054],
#         [ -57.3527,  -37.0689],
#         [  46.1557,   29.8339],
#         [ 202.2127,  130.7015],
#         [  43.0083,   27.7996]], grad_fn=<AddmmBackward0>)

# %%
plt.scatter(x2,y2[:,0])
plt.plot(x2, m2(x2).detach()[:,0])

# %%
plt.scatter(x2,y2[:,1])
plt.plot(x2, m2(x2).detach()[:,1])
